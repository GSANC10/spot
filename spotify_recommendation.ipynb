# %% [markdown]
# # Spotify Recommendation
#
# Before running the following code, ensure you have read the "Usage" section of the README.md file explaining how to use this notebook.

# %%
# Import necessary packages
import pandas as pd

# %%
# Returns a cleaned version of the given DataFrame (leaving the original unchanged)
def clean_data(df):
    
    # Create a deep copy of the DataFrame to ensure the original is unedited
    clean_df = df.copy()

    # Find duplicate tracks
    print('Finding duplicates...')
    dupe_mask = clean_df['track_id'].duplicated(keep=False)
    dupes = clean_df[dupe_mask].sort_values('track_id')
    print(f' - Total duplicated rows: {len(dupes)}')
    num_duplicated_songs = clean_df['track_id'].duplicated().sum()
    print(f' - Number of songs with duplicates: {num_duplicated_songs}')
    print('Done')

    # Remove duplicate tracks
    num_rows_before = len(clean_df)
    print(f'\nCurrent number of rows in DataFrame: {num_rows_before}')
    print('\nRemoving duplicates...')
    clean_df = clean_df.drop_duplicates(subset='track_id', keep='first')
    print('Done')
    num_rows_after = len(clean_df)
    print(f'\nNew number of rows in DataFrame: {num_rows_after}')
    print(f'Removed {num_rows_before - num_rows_after} duplicates')
    print(f'Number of unique track_ids: {clean_df['track_id'].nunique()}')

    # Drop unnecessary columns
    print('\nDropping the unnecessary columns "track_id" and "Unnamed: 0"...')
    clean_df = clean_df.drop('track_id', axis=1)
    clean_df = clean_df.drop('Unnamed: 0', axis=1)
    print('Done')

    return clean_df

# %%
# Create a DataFrame object from the dataset (in CSV format)
unclean_df = pd.read_csv('dataset.csv')

# Clean the data to remove duplicates and unnecessary columns
df = clean_data(unclean_df)

# Show a random sample of 10 tracks to view some of the data
df.sample(10)
# Out:
# Finding duplicates...
#  - Total duplicated rows: 40900
#  - Number of songs with duplicates: 24259
# Done
#
# Current number of rows in DataFrame: 114000
#
# Removing duplicates...
# Done
#
# New number of rows in DataFrame: 89741
# Removed 24259 duplicates
# Number of unique track_ids: 89741
#
# Dropping the unnecessary columns "track_id" and "Unnamed: 0"...
# Done
#                                   artists  \
# 17396           Glee Cast;Gwyneth Paltrow
# 61620                               AKB48
# 85832                  Drei Meter Feldweg
# 23489   Chris Lorenzo;LP Giobbi;High Jinx
# 50127                         Rata Blanca
# 83259            Dimitri Vangelis & Wyman
# 10390                Krafty Kuts;Sporty-O
# 45606                      Anna Kitkowska
# 41503             Within Temptation;Tarja
# 108822                   Domingo Federico
#
#                                                album_name  \
# 17396   Glee The 3D Concert Movie (Motion Picture Soun...
# 61620                                    UZA<Type-A>【通常盤】
# 85832                                            Gewinner
# 23489                                 California Dreamin'
# 50127                        Entre el Cielo y el Infierno
# 83259                                                Safe
# 10390                                          Let's Ride
# 45606                                      Anna Kitkowska
# 41503                                               Hydra
# 108822                      The Roots of Tango - Mi Dolor
#
#                                                track_name  popularity  \
# 17396                  Forget You (feat. Gwyneth Paltrow)          20
# 61620                                  次のSeason(アンダーガールズ)          21
# 85832                      Die Nacht, der Alkohol und wir          36
# 23489   California Dreamin' (feat. High Jinx) (LP Giob...          57
# 50127                             Sin Tu Amor Nada Existe          32
# 83259                                                Safe          64
# 10390                                          Let's Ride          14
# 45606                                 Love Me Like You Do          42
# 41503             Paradise (What About Us?) (feat. Tarja)          12
# 108822                           Para Que Te Quiero Tanto          16
#
#         duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 17396        162080     False         0.571   0.947    7    -4.695     1
# 61620        264706     False         0.468   0.919    8    -4.926     1
# 85832        175000     False         0.469   0.945    1    -3.986     0
# 23489        144761     False         0.610   0.966   11    -4.116     1
# 50127        354200     False         0.534   0.648    4   -12.992     1
# 83259        225230     False         0.360   0.845    0    -4.742     1
# 10390        261126     False         0.803   0.860   10    -4.065     0
# 45606        198208     False         0.635   0.231   11   -12.608     0
# 41503        319688     False         0.461   0.928    4    -3.542     0
# 108822       156544     False         0.651   0.200    1    -8.959     0
#
#         speechiness  acousticness  instrumentalness  liveness  valence  \
# 17396        0.0812      0.176000          0.000000    0.9000    0.579
# 61620        0.0513      0.189000          0.000007    0.3100    0.507
# 85832        0.0667      0.001590          0.000000    0.0816    0.463
# 23489        0.3050      0.000645          0.247000    0.3030    0.631
# 50127        0.0280      0.000927          0.031300    0.1650    0.428
# 83259        0.0344      0.031600          0.000034    0.0630    0.231
# 10390        0.1430      0.005830          0.000010    0.0453    0.603
# 45606        0.0419      0.939000          0.947000    0.0925    0.321
# 41503        0.0699      0.000580          0.001100    0.6150    0.433
# 108822       0.0819      0.956000          0.326000    0.2620    0.456
#
#           tempo  time_signature        track_genre
# 17396   127.411               4               club
# 61620    97.469               4             j-idol
# 85832    97.583               4          punk-rock
# 23489   126.001               4         deep-house
# 50127    96.077               4        heavy-metal
# 83259   130.066               4  progressive-house
# 10390   129.980               4          breakbeat
# 45606   144.229               4             guitar
# 41503   135.031               4               goth
# 108822  125.822               4              tango
